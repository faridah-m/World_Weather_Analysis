# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude caombinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Add the lats and lngs to a list
coordinates = list(lats_lngs)

# %%
# Import the dependencies.
import pandas as pd
from citipy import citipy

# %%
# Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
    try:
    # If the city is unique, then we will add it to the cities list.
        if city not in cities:
            cities.append(city)
    except():
        print("General Error... skipping.")   
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Import the requests library
import requests
# Import the API key
from config import weather_api_key
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=434b2a758c768d819662f177fbe8da0a

# %%
# Perform an API call with the OpenWeatherMap.

# Retrieve the following information from the API call:

## Latitude and longitude
## Maximum temperature
## Percent humidity
## Percent cloudiness
## Wind speed
## Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        # city_weather_main=city_weather["weather"][0]["main"]   
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          # "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | maniitsoq
# Processing Record 5 of Set 1 | hervey bay
# Processing Record 6 of Set 1 | kardailovo
# Processing Record 7 of Set 1 | brandfort
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | pimentel
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | launceston
# Processing Record 12 of Set 1 | olinda
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | dauphin
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | takoradi
# Processing Record 18 of Set 1 | tacotalpa
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | dalianwan
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | sitka
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | coquimbo
# Processing Record 28 of Set 1 | yulara
# Processing Record 29 of Set 1 | ngama
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | akyab
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | kamaishi
# Processing Record 36 of Set 1 | mabaruma
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | saint-joseph
# Processing Record 41 of Set 1 | bacuit
# City not found. Skipping...
# Processing Record 42 of Set 1 | marfino
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | loikaw
# Processing Record 45 of Set 1 | berdigestyakh
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | basco
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | mastung
# Processing Record 1 of Set 2 | guerrero negro
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | puerto narino
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | calvinia
# Processing Record 8 of Set 2 | tigil
# Processing Record 9 of Set 2 | alta floresta
# Processing Record 10 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 2 | tiznit
# Processing Record 12 of Set 2 | emerald
# Processing Record 13 of Set 2 | ocos
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | peniche
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | margate
# Processing Record 19 of Set 2 | sibolga
# Processing Record 20 of Set 2 | urozhaynoye
# Processing Record 21 of Set 2 | bratsk
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | diffa
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | vila franca do campo
# Processing Record 26 of Set 2 | sala
# Processing Record 27 of Set 2 | constitucion
# Processing Record 28 of Set 2 | hualmay
# Processing Record 29 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 2 | bell ville
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | sept-iles
# Processing Record 33 of Set 2 | mangai
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | shakhtinsk
# Processing Record 36 of Set 2 | chicama
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | dustlik
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | gberia fotombu
# Processing Record 41 of Set 2 | ribeirao bonito
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | dwarka
# Processing Record 45 of Set 2 | abu samrah
# Processing Record 46 of Set 2 | byron bay
# Processing Record 47 of Set 2 | bud
# Processing Record 48 of Set 2 | the pas
# Processing Record 49 of Set 2 | nikolskoye
# Processing Record 50 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | opuwo
# Processing Record 5 of Set 3 | santa fe
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | sobolevo
# Processing Record 8 of Set 3 | komsomolskiy
# Processing Record 9 of Set 3 | jiwani
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | gizo
# Processing Record 12 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 3 | divo
# Processing Record 14 of Set 3 | sabha
# Processing Record 15 of Set 3 | manggar
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | wahpeton
# Processing Record 19 of Set 3 | tamiahua
# Processing Record 20 of Set 3 | severo-kurilsk
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | nouadhibou
# Processing Record 23 of Set 3 | sur
# Processing Record 24 of Set 3 | semey
# Processing Record 25 of Set 3 | puerto colombia
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | matagami
# Processing Record 28 of Set 3 | berbera
# Processing Record 29 of Set 3 | pangnirtung
# Processing Record 30 of Set 3 | makinsk
# Processing Record 31 of Set 3 | anadyr
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 3 | berlevag
# Processing Record 35 of Set 3 | dikson
# Processing Record 36 of Set 3 | kavaratti
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | yar-sale
# Processing Record 39 of Set 3 | tasiilaq
# Processing Record 40 of Set 3 | fonte boa
# Processing Record 41 of Set 3 | la ronge
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 3 | tambura
# Processing Record 49 of Set 3 | sao joao da barra
# Processing Record 50 of Set 3 | cardoso
# Processing Record 1 of Set 4 | vanimo
# Processing Record 2 of Set 4 | oranjemund
# Processing Record 3 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 4 | palestine
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | aripuana
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | taraz
# Processing Record 11 of Set 4 | nicolas bravo
# Processing Record 12 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 4 | flinders
# Processing Record 14 of Set 4 | tiksi
# Processing Record 15 of Set 4 | laguna
# Processing Record 16 of Set 4 | saint-pierre
# Processing Record 17 of Set 4 | sokone
# Processing Record 18 of Set 4 | klaksvik
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | samarkand
# Processing Record 21 of Set 4 | kenai
# Processing Record 22 of Set 4 | lorengau
# Processing Record 23 of Set 4 | coahuayana
# Processing Record 24 of Set 4 | mirnyy
# Processing Record 25 of Set 4 | iqaluit
# Processing Record 26 of Set 4 | lavumisa
# Processing Record 27 of Set 4 | urumqi
# Processing Record 28 of Set 4 | umm lajj
# Processing Record 29 of Set 4 | miandrivazo
# Processing Record 30 of Set 4 | carutapera
# Processing Record 31 of Set 4 | shu
# Processing Record 32 of Set 4 | beloha
# Processing Record 33 of Set 4 | northam
# Processing Record 34 of Set 4 | bereda
# Processing Record 35 of Set 4 | bathsheba
# Processing Record 36 of Set 4 | cherskiy
# Processing Record 37 of Set 4 | acapulco
# Processing Record 38 of Set 4 | antofagasta
# Processing Record 39 of Set 4 | harper
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | olafsvik
# Processing Record 42 of Set 4 | naze
# Processing Record 43 of Set 4 | bonthe
# Processing Record 44 of Set 4 | bairiki
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | mount isa
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | koksovyy
# Processing Record 49 of Set 4 | bontang
# Processing Record 50 of Set 4 | caraquet
# Processing Record 1 of Set 5 | pacific grove
# Processing Record 2 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 5 | biak
# Processing Record 4 of Set 5 | partizanskoye
# Processing Record 5 of Set 5 | alugan
# Processing Record 6 of Set 5 | gamba
# Processing Record 7 of Set 5 | la tuque
# Processing Record 8 of Set 5 | port alfred
# Processing Record 9 of Set 5 | pocone
# Processing Record 10 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 5 | los llanos de aridane
# Processing Record 12 of Set 5 | sumbe
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | kutum
# Processing Record 15 of Set 5 | puksoozero
# Processing Record 16 of Set 5 | miri
# Processing Record 17 of Set 5 | ridgecrest
# Processing Record 18 of Set 5 | kodiak
# Processing Record 19 of Set 5 | kavieng
# Processing Record 20 of Set 5 | moyo
# Processing Record 21 of Set 5 | mayumba
# Processing Record 22 of Set 5 | haicheng
# Processing Record 23 of Set 5 | tessalit
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 5 | sri aman
# Processing Record 27 of Set 5 | puerto ayora
# Processing Record 28 of Set 5 | hofn
# Processing Record 29 of Set 5 | mount pleasant
# Processing Record 30 of Set 5 | batagay
# Processing Record 31 of Set 5 | hecun
# Processing Record 32 of Set 5 | baglan
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | anjiang
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | nome
# Processing Record 37 of Set 5 | cavalcante
# Processing Record 38 of Set 5 | camacha
# Processing Record 39 of Set 5 | kodinsk
# Processing Record 40 of Set 5 | raudeberg
# Processing Record 41 of Set 5 | biloela
# Processing Record 42 of Set 5 | faanui
# Processing Record 43 of Set 5 | eureka
# Processing Record 44 of Set 5 | springdale
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | yantzaza
# Processing Record 47 of Set 5 | banjar
# Processing Record 48 of Set 5 | pangody
# Processing Record 49 of Set 5 | puerto escondido
# Processing Record 50 of Set 5 | sapernoye
# Processing Record 1 of Set 6 | piacabucu
# Processing Record 2 of Set 6 | beringovskiy
# Processing Record 3 of Set 6 | pemangkat
# Processing Record 4 of Set 6 | kibondo
# Processing Record 5 of Set 6 | baykit
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | muroto
# Processing Record 8 of Set 6 | bilma
# Processing Record 9 of Set 6 | hasaki
# Processing Record 10 of Set 6 | biltine
# Processing Record 11 of Set 6 | antalaha
# Processing Record 12 of Set 6 | red bluff
# Processing Record 13 of Set 6 | victoria falls
# Processing Record 14 of Set 6 | maldonado
# Processing Record 15 of Set 6 | broken hill
# Processing Record 16 of Set 6 | peterborough
# Processing Record 17 of Set 6 | hit
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | kosino
# Processing Record 23 of Set 6 | adre
# Processing Record 24 of Set 6 | ostrovnoy
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | trelew
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | fairbanks
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | ilulissat
# Processing Record 31 of Set 6 | saint-quentin
# Processing Record 32 of Set 6 | port blair
# Processing Record 33 of Set 6 | azrow
# City not found. Skipping...
# Processing Record 34 of Set 6 | hammerfest
# Processing Record 35 of Set 6 | taoudenni
# Processing Record 36 of Set 6 | rabo de peixe
# Processing Record 37 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 6 | srivardhan
# Processing Record 39 of Set 6 | cacoal
# Processing Record 40 of Set 6 | husavik
# Processing Record 41 of Set 6 | churapcha
# Processing Record 42 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 6 | sokoto
# Processing Record 44 of Set 6 | picton
# Processing Record 45 of Set 6 | tefe
# Processing Record 46 of Set 6 | grindavik
# Processing Record 47 of Set 6 | jinchang
# Processing Record 48 of Set 6 | gat
# Processing Record 49 of Set 6 | alofi
# Processing Record 50 of Set 6 | tucuman
# Processing Record 1 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 2 of Set 7 | kunya
# Processing Record 3 of Set 7 | honiara
# Processing Record 4 of Set 7 | wukari
# Processing Record 5 of Set 7 | tonantins
# Processing Record 6 of Set 7 | kenora
# Processing Record 7 of Set 7 | carnarvon
# Processing Record 8 of Set 7 | oliver
# Processing Record 9 of Set 7 | maraa
# Processing Record 10 of Set 7 | ngorongoro
# Processing Record 11 of Set 7 | sao felix do xingu
# Processing Record 12 of Set 7 | winona
# Processing Record 13 of Set 7 | te anau
# Processing Record 14 of Set 7 | madimba
# Processing Record 15 of Set 7 | abu dhabi
# Processing Record 16 of Set 7 | gaoua
# Processing Record 17 of Set 7 | khovu-aksy
# Processing Record 18 of Set 7 | pierre
# Processing Record 19 of Set 7 | norman wells
# Processing Record 20 of Set 7 | havoysund
# Processing Record 21 of Set 7 | dunedin
# Processing Record 22 of Set 7 | gobabis
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | riyadh
# Processing Record 25 of Set 7 | southbridge
# Processing Record 26 of Set 7 | port townsend
# Processing Record 27 of Set 7 | darhan
# Processing Record 28 of Set 7 | shemonaikha
# Processing Record 29 of Set 7 | ambovombe
# Processing Record 30 of Set 7 | gumdag
# Processing Record 31 of Set 7 | cabo san lucas
# Processing Record 32 of Set 7 | sotouboua
# Processing Record 33 of Set 7 | clemencia
# Processing Record 34 of Set 7 | urucara
# Processing Record 35 of Set 7 | chulman
# Processing Record 36 of Set 7 | novopokrovka
# Processing Record 37 of Set 7 | salta
# Processing Record 38 of Set 7 | hamilton
# Processing Record 39 of Set 7 | san quintin
# Processing Record 40 of Set 7 | shishou
# Processing Record 41 of Set 7 | muhos
# Processing Record 42 of Set 7 | padang
# Processing Record 43 of Set 7 | khasan
# Processing Record 44 of Set 7 | hambantota
# Processing Record 45 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 7 | vao
# Processing Record 47 of Set 7 | portland
# Processing Record 48 of Set 7 | benito juarez
# Processing Record 49 of Set 7 | geraldton
# Processing Record 50 of Set 7 | addi ugri
# City not found. Skipping...
# Processing Record 1 of Set 8 | khorixas
# Processing Record 2 of Set 8 | gbadolite
# Processing Record 3 of Set 8 | abha
# Processing Record 4 of Set 8 | virginia beach
# Processing Record 5 of Set 8 | zhetybay
# City not found. Skipping...
# Processing Record 6 of Set 8 | purpe
# Processing Record 7 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 8 of Set 8 | mana
# Processing Record 9 of Set 8 | tipp city
# Processing Record 10 of Set 8 | katsuura
# Processing Record 11 of Set 8 | salinas
# Processing Record 12 of Set 8 | micheweni
# Processing Record 13 of Set 8 | razole
# Processing Record 14 of Set 8 | tarakan
# Processing Record 15 of Set 8 | mehamn
# Processing Record 16 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 8 | moron
# Processing Record 18 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 8 | alice springs
# Processing Record 20 of Set 8 | tignere
# Processing Record 21 of Set 8 | ariquemes
# Processing Record 22 of Set 8 | saldanha
# Processing Record 23 of Set 8 | taltal
# Processing Record 24 of Set 8 | sembe
# Processing Record 25 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 8 | san ignacio
# Processing Record 27 of Set 8 | marsa matruh
# Processing Record 28 of Set 8 | cayenne
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 8 | grootfontein
# Processing Record 32 of Set 8 | muravlenko
# Processing Record 33 of Set 8 | illapel
# Processing Record 34 of Set 8 | orapa
# Processing Record 35 of Set 8 | kieta
# Processing Record 36 of Set 8 | yambio
# Processing Record 37 of Set 8 | kapit
# Processing Record 38 of Set 8 | cozumel
# Processing Record 39 of Set 8 | half moon bay
# Processing Record 40 of Set 8 | ajdabiya
# Processing Record 41 of Set 8 | yining
# Processing Record 42 of Set 8 | sharya
# Processing Record 43 of Set 8 | isangel
# Processing Record 44 of Set 8 | hagi
# Processing Record 45 of Set 8 | caravelas
# Processing Record 46 of Set 8 | marivan
# Processing Record 47 of Set 8 | pacifica
# Processing Record 48 of Set 8 | ivanivka
# Processing Record 49 of Set 8 | lejanias
# Processing Record 50 of Set 8 | dongsheng
# Processing Record 1 of Set 9 | walvis bay
# Processing Record 2 of Set 9 | pilar
# Processing Record 3 of Set 9 | tomatlan
# Processing Record 4 of Set 9 | aguilas
# Processing Record 5 of Set 9 | bambous virieux
# Processing Record 6 of Set 9 | liverpool
# Processing Record 7 of Set 9 | shingu
# Processing Record 8 of Set 9 | mayor pablo lagerenza
# Processing Record 9 of Set 9 | port lincoln
# Processing Record 10 of Set 9 | russellville
# Processing Record 11 of Set 9 | tautira
# Processing Record 12 of Set 9 | mantua
# Processing Record 13 of Set 9 | esterhazy
# Processing Record 14 of Set 9 | tommot
# Processing Record 15 of Set 9 | hunterville
# Processing Record 16 of Set 9 | bloomsburg
# Processing Record 17 of Set 9 | quesnel
# Processing Record 18 of Set 9 | yuanping
# Processing Record 19 of Set 9 | kasulu
# Processing Record 20 of Set 9 | corpus christi
# Processing Record 21 of Set 9 | port pirie
# Processing Record 22 of Set 9 | lhuntshi
# City not found. Skipping...
# Processing Record 23 of Set 9 | dom pedrito
# Processing Record 24 of Set 9 | avera
# Processing Record 25 of Set 9 | sindor
# Processing Record 26 of Set 9 | wageningen
# Processing Record 27 of Set 9 | kamina
# Processing Record 28 of Set 9 | ginda
# Processing Record 29 of Set 9 | kwinana
# Processing Record 30 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 31 of Set 9 | salalah
# Processing Record 32 of Set 9 | road town
# Processing Record 33 of Set 9 | cururupu
# Processing Record 34 of Set 9 | gold coast
# Processing Record 35 of Set 9 | santa maria del oro
# Processing Record 36 of Set 9 | zhezkazgan
# Processing Record 37 of Set 9 | wenshang
# Processing Record 38 of Set 9 | lumeje
# Processing Record 39 of Set 9 | fukue
# Processing Record 40 of Set 9 | gilazi
# City not found. Skipping...
# Processing Record 41 of Set 9 | shitanjing
# Processing Record 42 of Set 9 | freetown
# Processing Record 43 of Set 9 | manadhoo
# Processing Record 44 of Set 9 | vila velha
# Processing Record 45 of Set 9 | uyuni
# Processing Record 46 of Set 9 | manono
# Processing Record 47 of Set 9 | chipinge
# Processing Record 48 of Set 9 | mpika
# Processing Record 49 of Set 9 | pagudpud
# Processing Record 50 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 10 | altay
# Processing Record 2 of Set 10 | melbu
# Processing Record 3 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 10 | rundu
# Processing Record 5 of Set 10 | zanjan
# Processing Record 6 of Set 10 | kayerkan
# Processing Record 7 of Set 10 | lasa
# Processing Record 8 of Set 10 | nuevo progreso
# Processing Record 9 of Set 10 | mahibadhoo
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | isabela
# Processing Record 12 of Set 10 | changji
# Processing Record 13 of Set 10 | ballina
# Processing Record 14 of Set 10 | teahupoo
# Processing Record 15 of Set 10 | san juan
# Processing Record 16 of Set 10 | harsin
# Processing Record 17 of Set 10 | nova olimpia
# Processing Record 18 of Set 10 | tura
# Processing Record 19 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | namibe
# Processing Record 21 of Set 10 | gaozhou
# Processing Record 22 of Set 10 | lobito
# Processing Record 23 of Set 10 | andrews
# Processing Record 24 of Set 10 | dingle
# Processing Record 25 of Set 10 | yantal
# Processing Record 26 of Set 10 | voh
# Processing Record 27 of Set 10 | moirang
# Processing Record 28 of Set 10 | minab
# Processing Record 29 of Set 10 | mogadishu
# Processing Record 30 of Set 10 | port-gentil
# Processing Record 31 of Set 10 | dombarovskiy
# Processing Record 32 of Set 10 | cap malheureux
# Processing Record 33 of Set 10 | nicolas de pierola
# Processing Record 34 of Set 10 | krasnoselkup
# Processing Record 35 of Set 10 | kalakamati
# Processing Record 36 of Set 10 | borgarnes
# Processing Record 37 of Set 10 | abu kamal
# Processing Record 38 of Set 10 | breves
# Processing Record 39 of Set 10 | sesimbra
# Processing Record 40 of Set 10 | ulaanbaatar
# Processing Record 41 of Set 10 | kaili
# Processing Record 42 of Set 10 | robertson
# Processing Record 43 of Set 10 | westport
# Processing Record 44 of Set 10 | valle hermoso
# Processing Record 45 of Set 10 | sungairaya
# Processing Record 46 of Set 10 | bandundu
# Processing Record 47 of Set 10 | ponta delgada
# Processing Record 48 of Set 10 | yagodnoye
# Processing Record 49 of Set 10 | miragoane
# Processing Record 50 of Set 10 | okha
# Processing Record 1 of Set 11 | puerto baquerizo moreno
# Processing Record 2 of Set 11 | molteno
# Processing Record 3 of Set 11 | tibagi
# Processing Record 4 of Set 11 | iracoubo
# Processing Record 5 of Set 11 | karatau
# Processing Record 6 of Set 11 | bafoulabe
# Processing Record 7 of Set 11 | moreira sales
# Processing Record 8 of Set 11 | zonguldak
# Processing Record 9 of Set 11 | yumen
# Processing Record 10 of Set 11 | kuah
# Processing Record 11 of Set 11 | yantongshan
# Processing Record 12 of Set 11 | george
# Processing Record 13 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 11 | slave lake
# Processing Record 15 of Set 11 | bam
# Processing Record 16 of Set 11 | broome
# Processing Record 17 of Set 11 | rochegda
# Processing Record 18 of Set 11 | yarada
# Processing Record 19 of Set 11 | clyde
# Processing Record 20 of Set 11 | victoria
# Processing Record 21 of Set 11 | gilgit
# Processing Record 22 of Set 11 | berezovka
# Processing Record 23 of Set 11 | havre-saint-pierre
# Processing Record 24 of Set 11 | sechura
# Processing Record 25 of Set 11 | sar-e pul
# Processing Record 26 of Set 11 | yuzhno-sukhokumsk
# Processing Record 27 of Set 11 | kalispell
# Processing Record 28 of Set 11 | casper
# Processing Record 29 of Set 11 | ak-dovurak
# Processing Record 30 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 11 | beech grove
# Processing Record 32 of Set 11 | saint-georges
# Processing Record 33 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 34 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 11 | groa
# Processing Record 36 of Set 11 | san policarpo
# Processing Record 37 of Set 11 | hobyo
# Processing Record 38 of Set 11 | itaituba
# Processing Record 39 of Set 11 | puri
# Processing Record 40 of Set 11 | esperance
# Processing Record 41 of Set 11 | kaitangata
# Processing Record 42 of Set 11 | labuhan
# Processing Record 43 of Set 11 | hirado
# Processing Record 44 of Set 11 | bahia blanca
# Processing Record 45 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 46 of Set 11 | vuktyl
# Processing Record 47 of Set 11 | nelson bay
# Processing Record 48 of Set 11 | tandil
# Processing Record 49 of Set 11 | novi ligure
# Processing Record 50 of Set 11 | goedereede
# Processing Record 1 of Set 12 | thunder bay
# Processing Record 2 of Set 12 | balakhninskiy
# Processing Record 3 of Set 12 | banda aceh
# Processing Record 4 of Set 12 | anori
# Processing Record 5 of Set 12 | damara
# Processing Record 6 of Set 12 | ust-barguzin
# Processing Record 7 of Set 12 | kijang
# Processing Record 8 of Set 12 | wuxue
# Processing Record 9 of Set 12 | fortuna
# Processing Record 10 of Set 12 | jiayuguan
# Processing Record 11 of Set 12 | brae
# Processing Record 12 of Set 12 | djenne
# Processing Record 13 of Set 12 | sirjan
# Processing Record 14 of Set 12 | nyuksenitsa
# Processing Record 15 of Set 12 | marsh harbour
# Processing Record 16 of Set 12 | kupang
# Processing Record 17 of Set 12 | aktau
# Processing Record 18 of Set 12 | jinxiang
# Processing Record 19 of Set 12 | talara
# Processing Record 20 of Set 12 | lufilufi
# Processing Record 21 of Set 12 | mecca
# Processing Record 22 of Set 12 | shenjiamen
# Processing Record 23 of Set 12 | ambon
# Processing Record 24 of Set 12 | touros
# Processing Record 25 of Set 12 | rovaniemi
# Processing Record 26 of Set 12 | vila
# Processing Record 27 of Set 12 | sao filipe
# Processing Record 28 of Set 12 | letterkenny
# Processing Record 29 of Set 12 | yamethin
# Processing Record 30 of Set 12 | cap-aux-meules
# Processing Record 31 of Set 12 | ejutla de crespo
# Processing Record 32 of Set 12 | marzuq
# Processing Record 33 of Set 12 | rapid valley
# Processing Record 34 of Set 12 | hirara
# Processing Record 35 of Set 12 | ulma
# Processing Record 36 of Set 12 | hargeysa
# Processing Record 37 of Set 12 | belyy yar
# Processing Record 38 of Set 12 | ardakan
# Processing Record 39 of Set 12 | aiyira
# Processing Record 40 of Set 12 | gremyachinsk
# Processing Record 41 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 12 | kahului
# Processing Record 43 of Set 12 | cravo norte
# Processing Record 44 of Set 12 | sayyan
# Processing Record 45 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 12 | severobaykalsk
# Processing Record 47 of Set 12 | nizwa
# Processing Record 48 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 12 | talnakh
# Processing Record 50 of Set 12 | boa esperanca
# Processing Record 1 of Set 13 | kathu
# Processing Record 2 of Set 13 | mitsamiouli
# Processing Record 3 of Set 13 | sovetskiy
# Processing Record 4 of Set 13 | quelimane
# Processing Record 5 of Set 13 | sidi ali
# Processing Record 6 of Set 13 | nabire
# Processing Record 7 of Set 13 | darnah
# Processing Record 8 of Set 13 | suntar
# Processing Record 9 of Set 13 | lensk
# Processing Record 10 of Set 13 | emirdag
# Processing Record 11 of Set 13 | muisne
# Processing Record 12 of Set 13 | jaguariaiva
# Processing Record 13 of Set 13 | vardo
# Processing Record 14 of Set 13 | picos
# Processing Record 15 of Set 13 | adrar
# Processing Record 16 of Set 13 | taganak
# Processing Record 17 of Set 13 | wawa
# Processing Record 18 of Set 13 | willmar
# Processing Record 19 of Set 13 | mahenge
# Processing Record 20 of Set 13 | sabi
# Processing Record 21 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 13 | esso
# Processing Record 23 of Set 13 | srednekolymsk
# Processing Record 24 of Set 13 | pervomayskoye
# Processing Record 25 of Set 13 | najran
# Processing Record 26 of Set 13 | fairlie
# Processing Record 27 of Set 13 | lithakia
# Processing Record 28 of Set 13 | coihaique
# Processing Record 29 of Set 13 | roswell
# Processing Record 30 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 13 | necochea
# Processing Record 32 of Set 13 | dubai
# Processing Record 33 of Set 13 | pakokku
# Processing Record 34 of Set 13 | ancud
# Processing Record 35 of Set 13 | pangai
# Processing Record 36 of Set 13 | chippewa falls
# Processing Record 37 of Set 13 | ngong
# Processing Record 38 of Set 13 | asau
# Processing Record 39 of Set 13 | fort saint james
# Processing Record 40 of Set 13 | costa rica
# Processing Record 41 of Set 13 | boali
# Processing Record 42 of Set 13 | sassandra
# Processing Record 43 of Set 13 | shaikhpura
# Processing Record 44 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 13 | port hardy
# Processing Record 46 of Set 13 | vostok
# Processing Record 47 of Set 13 | leh
# Processing Record 48 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 13 | balad
# Processing Record 50 of Set 13 | sola
# Processing Record 1 of Set 14 | le port
# Processing Record 2 of Set 14 | luanda
# Processing Record 3 of Set 14 | xuchang
# Processing Record 4 of Set 14 | chingirlau
# Processing Record 5 of Set 14 | chara
# Processing Record 6 of Set 14 | cangzhou
# Processing Record 7 of Set 14 | sarzedo
# Processing Record 8 of Set 14 | boyolangu
# Processing Record 9 of Set 14 | saint-augustin
# Processing Record 10 of Set 14 | balikpapan
# Processing Record 11 of Set 14 | shubarkuduk
# Processing Record 12 of Set 14 | sajalices
# Processing Record 13 of Set 14 | puerto madryn
# Processing Record 14 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 15 of Set 14 | gull lake
# Processing Record 16 of Set 14 | nikolayevsk-na-amure
# Processing Record 17 of Set 14 | torbay
# Processing Record 18 of Set 14 | salmo
# Processing Record 19 of Set 14 | meulaboh
# Processing Record 20 of Set 14 | platanos
# Processing Record 21 of Set 14 | comodoro rivadavia
# Processing Record 22 of Set 14 | mweka
# Processing Record 23 of Set 14 | aswan
# Processing Record 24 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 14 | porto novo
# Processing Record 26 of Set 14 | mnogovershinnyy
# Processing Record 27 of Set 14 | dunkirk
# Processing Record 28 of Set 14 | poum
# Processing Record 29 of Set 14 | santa cruz
# Processing Record 30 of Set 14 | dezful
# Processing Record 31 of Set 14 | zavoronezhskoye
# Processing Record 32 of Set 14 | ayan
# Processing Record 33 of Set 14 | moyobamba
# Processing Record 34 of Set 14 | quatre cocos
# Processing Record 35 of Set 14 | vestmanna
# Processing Record 36 of Set 14 | sao lourenco do sul
# Processing Record 37 of Set 14 | axim
# Processing Record 38 of Set 14 | kurilsk
# Processing Record 39 of Set 14 | novyy urengoy
# Processing Record 40 of Set 14 | port augusta
# Processing Record 41 of Set 14 | port hedland
# Processing Record 42 of Set 14 | spornoye
# Processing Record 43 of Set 14 | areosa
# Processing Record 44 of Set 14 | ladario
# Processing Record 45 of Set 14 | san bernardo
# Processing Record 46 of Set 14 | cooma
# Processing Record 47 of Set 14 | cerignola
# Processing Record 48 of Set 14 | ratnagiri
# Processing Record 49 of Set 14 | rocha
# Processing Record 50 of Set 14 | itarema
# Processing Record 1 of Set 15 | nova varos
# Processing Record 2 of Set 15 | leningradskiy
# Processing Record 3 of Set 15 | aykhal
# Processing Record 4 of Set 15 | palani
# Processing Record 5 of Set 15 | taksimo
# Processing Record 6 of Set 15 | gavle
# Processing Record 7 of Set 15 | santa rosa
# Processing Record 8 of Set 15 | sandakan
# Processing Record 9 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 10 of Set 15 | tucurui
# Processing Record 11 of Set 15 | boddam
# Processing Record 12 of Set 15 | benalla
# Processing Record 13 of Set 15 | rondonopolis
# Processing Record 14 of Set 15 | peruibe
# Processing Record 15 of Set 15 | doha
# Processing Record 16 of Set 15 | pontianak
# Processing Record 17 of Set 15 | caxias
# Processing Record 18 of Set 15 | brownwood
# Processing Record 19 of Set 15 | kandalaksha
# Processing Record 20 of Set 15 | maceio
# Processing Record 21 of Set 15 | vestmannaeyjar
# Processing Record 22 of Set 15 | elat
# Processing Record 23 of Set 15 | urengoy
# Processing Record 24 of Set 15 | lannion
# Processing Record 25 of Set 15 | wagar
# Processing Record 26 of Set 15 | miraflores
# Processing Record 27 of Set 15 | shirokiy
# Processing Record 28 of Set 15 | plettenberg bay
# Processing Record 29 of Set 15 | duz
# City not found. Skipping...
# Processing Record 30 of Set 15 | sorong
# Processing Record 31 of Set 15 | medea
# Processing Record 32 of Set 15 | ikom
# Processing Record 33 of Set 15 | evans
# Processing Record 34 of Set 15 | araouane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bredasdorp      ZA -34.5322   20.0403     66.20        72          75
# 1     Rikitea      PF -23.1203 -134.9692     79.29        73           5
# 2      Albany      US  42.6001  -73.9662     34.00        65         100
# 3   Maniitsoq      GL  65.4167  -52.9000      2.62        81           7
# 4  Hervey Bay      AU -25.2986  152.8535     75.00        81          25
# 5  Kardailovo      RU  51.5386   53.9042     -7.38        87         100
# 6   Brandfort      ZA -28.7001   26.4597     59.00        82           0
# 7        Lebu      CL -37.6167  -73.6500     57.54        75           0
# 8    Pimentel      PE  -6.8367  -79.9342     78.80        57           0
# 9      Atuona      PF  -9.8000 -139.0333     79.27        78          21
#
#    Wind Speed Current Description
# 0       10.36       broken clouds
# 1       12.08           clear sky
# 2        7.00     overcast clouds
# 3        6.11           clear sky
# 4        8.01    scattered clouds
# 5        6.73     overcast clouds
# 6        5.75           clear sky
# 7       12.62           clear sky
# 8       24.16           clear sky
# 9       14.56          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
